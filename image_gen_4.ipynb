# %% [markdown]
# based on: https://www.tensorflow.org/tutorials/generative/cyclegan
# and: https://github.com/tensorflow/examples/blob/master/tensorflow_examples/models/pix2pix/pix2pix.py

# %%
import tensorflow as tf

if tf.test.gpu_device_name():
    print(f"Default GPU Device: {tf.test.gpu_device_name()}")

# %%
import tensorflow_datasets as tfds

import os
import time
import matplotlib.pyplot as plt
from IPython.display import clear_output

# AUTOTUNE = tf.data.AUTOTUNE

# %% [markdown]
# ## Data Preprocessing

# %%
dataset, metadata = tfds.load("cycle_gan/horse2zebra", with_info=True, as_supervised=True)

train_horses, train_zebras = dataset["trainA"], dataset["trainB"]
test_horses, test_zebras = dataset["testA"], dataset["testB"]
# Out:
# Downloading and preparing dataset 111.45 MiB (download: 111.45 MiB, generated: Unknown size, total: 111.45 MiB) to /Users/jules/tensorflow_datasets/cycle_gan/horse2zebra/2.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Dl Completed...:   0%|          | 0/1 [00:00<?, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Dl Completed...:   0%|          | 0/1 [00:00<?, ? url/s]
# Dl Size...:   0%|          | 0/111 [00:00<?, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:00<?, ? url/s]
# Dl Size...:   1%|          | 1/111 [00:00<01:04,  1.70 MiB/s]
#
# Dl Completed...:   0%|          | 0/1 [00:00<?, ? url/s]
# Dl Size...:   2%|▏         | 2/111 [00:00<01:04,  1.70 MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:00<?, ? url/s]
# Dl Size...:   3%|▎         | 3/111 [00:00<00:49,  2.18 MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:01<?, ? url/s]
# Dl Size...:   4%|▎         | 4/111 [00:01<00:42,  2.49 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:01<?, ? url/s]
# Dl Size...:   5%|▍         | 5/111 [00:01<00:38,  2.73 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:01<?, ? url/s]
# Dl Size...:   5%|▌         | 6/111 [00:01<00:35,  2.98 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:02<?, ? url/s]
# Dl Size...:   6%|▋         | 7/111 [00:02<00:33,  3.14 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:02<?, ? url/s]
# Dl Size...:   7%|▋         | 8/111 [00:02<00:32,  3.15 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:02<?, ? url/s]
# Dl Size...:   8%|▊         | 9/111 [00:02<00:35,  2.89 MiB/s]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:03<?, ? url/s]
# Dl Size...:   9%|▉         | 10/111 [00:03<00:34,  2.91 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:03<?, ? url/s]
# Dl Size...:  10%|▉         | 11/111 [00:03<00:33,  3.01 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:03<?, ? url/s]
# Dl Size...:  11%|█         | 12/111 [00:03<00:32,  3.09 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:03<?, ? url/s]
# Dl Size...:  12%|█▏        | 13/111 [00:03<00:30,  3.19 MiB/s]
#
# Extraction completed...: 0 file [00:03, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:04<?, ? url/s]
# Dl Size...:  13%|█▎        | 14/111 [00:04<00:29,  3.31 MiB/s]
#
# Extraction completed...: 0 file [00:04, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:04<?, ? url/s]
# Dl Size...:  14%|█▎        | 15/111 [00:04<00:28,  3.41 MiB/s]
#
# Extraction completed...: 0 file [00:04, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:04<?, ? url/s]
# Dl Size...:  14%|█▍        | 16/111 [00:04<00:27,  3.48 MiB/s]
#
# Extraction completed...: 0 file [00:04, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:05<?, ? url/s]
# Dl Size...:  15%|█▌        | 17/111 [00:05<00:28,  3.32 MiB/s]
#
# Extraction completed...: 0 file [00:05, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:05<?, ? url/s]
# Dl Size...:  16%|█▌        | 18/111 [00:05<00:28,  3.32 MiB/s]
#
# Extraction completed...: 0 file [00:05, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:05<?, ? url/s]
# Dl Size...:  17%|█▋        | 19/111 [00:05<00:27,  3.33 MiB/s]
#
# Extraction completed...: 0 file [00:05, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:06<?, ? url/s]
# Dl Size...:  18%|█▊        | 20/111 [00:05<00:26,  3.40 MiB/s]
#
# Extraction completed...: 0 file [00:05, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:06<?, ? url/s]
# Dl Size...:  19%|█▉        | 21/111 [00:06<00:27,  3.33 MiB/s]
#
# Extraction completed...: 0 file [00:06, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:06<?, ? url/s]
# Dl Size...:  20%|█▉        | 22/111 [00:06<00:27,  3.19 MiB/s]
#
# Extraction completed...: 0 file [00:06, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:07<?, ? url/s]
# Dl Size...:  21%|██        | 23/111 [00:07<00:29,  2.99 MiB/s]
#
# Extraction completed...: 0 file [00:07, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:07<?, ? url/s]
# Dl Size...:  22%|██▏       | 24/111 [00:07<00:28,  3.03 MiB/s]
#
# Extraction completed...: 0 file [00:07, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:07<?, ? url/s]
# Dl Size...:  23%|██▎       | 25/111 [00:07<00:27,  3.14 MiB/s]
#
# Extraction completed...: 0 file [00:07, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:07<?, ? url/s]
# Dl Size...:  23%|██▎       | 26/111 [00:07<00:27,  3.09 MiB/s]
#
# Extraction completed...: 0 file [00:07, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:08<?, ? url/s]
# Dl Size...:  24%|██▍       | 27/111 [00:08<00:26,  3.15 MiB/s]
#
# Extraction completed...: 0 file [00:08, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:08<?, ? url/s]
# Dl Size...:  25%|██▌       | 28/111 [00:08<00:25,  3.19 MiB/s]
#
# Extraction completed...: 0 file [00:08, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:08<?, ? url/s]
# Dl Size...:  26%|██▌       | 29/111 [00:08<00:25,  3.25 MiB/s]
#
# Extraction completed...: 0 file [00:08, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:09<?, ? url/s]
# Dl Size...:  27%|██▋       | 30/111 [00:09<00:24,  3.37 MiB/s]
#
# Extraction completed...: 0 file [00:09, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:09<?, ? url/s]
# Dl Size...:  28%|██▊       | 31/111 [00:09<00:24,  3.31 MiB/s]
#
# Extraction completed...: 0 file [00:09, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:09<?, ? url/s]
# Dl Size...:  29%|██▉       | 32/111 [00:09<00:23,  3.33 MiB/s]
#
# Extraction completed...: 0 file [00:09, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:10<?, ? url/s]
# Dl Size...:  30%|██▉       | 33/111 [00:10<00:22,  3.41 MiB/s]
#
# Extraction completed...: 0 file [00:10, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:10<?, ? url/s]
# Dl Size...:  31%|███       | 34/111 [00:10<00:21,  3.51 MiB/s]
#
# Extraction completed...: 0 file [00:10, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:10<?, ? url/s]
# Dl Size...:  32%|███▏      | 35/111 [00:10<00:21,  3.58 MiB/s]
#
# Extraction completed...: 0 file [00:10, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:10<?, ? url/s]
# Dl Size...:  32%|███▏      | 36/111 [00:10<00:20,  3.63 MiB/s]
#
# Extraction completed...: 0 file [00:10, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:11<?, ? url/s]
# Dl Size...:  33%|███▎      | 37/111 [00:11<00:19,  3.74 MiB/s]
#
# Extraction completed...: 0 file [00:11, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:11<?, ? url/s]
# Dl Size...:  34%|███▍      | 38/111 [00:11<00:20,  3.57 MiB/s]
#
# Extraction completed...: 0 file [00:11, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:11<?, ? url/s]
# Dl Size...:  35%|███▌      | 39/111 [00:11<00:21,  3.30 MiB/s]
#
# Extraction completed...: 0 file [00:11, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:12<?, ? url/s]
# Dl Size...:  36%|███▌      | 40/111 [00:12<00:22,  3.15 MiB/s]
#
# Extraction completed...: 0 file [00:12, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:12<?, ? url/s]
# Dl Size...:  37%|███▋      | 41/111 [00:12<00:24,  2.92 MiB/s]
#
# Extraction completed...: 0 file [00:12, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:12<?, ? url/s]
# Dl Size...:  38%|███▊      | 42/111 [00:12<00:23,  2.97 MiB/s]
#
# Extraction completed...: 0 file [00:12, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:13<?, ? url/s]
# Dl Size...:  39%|███▊      | 43/111 [00:13<00:24,  2.77 MiB/s]
#
# Extraction completed...: 0 file [00:13, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:13<?, ? url/s]
# Dl Size...:  40%|███▉      | 44/111 [00:13<00:25,  2.61 MiB/s]
#
# Extraction completed...: 0 file [00:13, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:14<?, ? url/s]
# Dl Size...:  41%|████      | 45/111 [00:14<00:25,  2.58 MiB/s]
#
# Extraction completed...: 0 file [00:14, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:14<?, ? url/s]
# Dl Size...:  41%|████▏     | 46/111 [00:14<00:27,  2.38 MiB/s]
#
# Extraction completed...: 0 file [00:14, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:15<?, ? url/s]
# Dl Size...:  42%|████▏     | 47/111 [00:15<00:27,  2.36 MiB/s]
#
# Extraction completed...: 0 file [00:15, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:15<?, ? url/s]
# Dl Size...:  43%|████▎     | 48/111 [00:15<00:26,  2.41 MiB/s]
#
# Extraction completed...: 0 file [00:15, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:15<?, ? url/s]
# Dl Size...:  44%|████▍     | 49/111 [00:15<00:25,  2.45 MiB/s]
#
# Extraction completed...: 0 file [00:15, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:16<?, ? url/s]
# Dl Size...:  45%|████▌     | 50/111 [00:16<00:24,  2.50 MiB/s]
#
# Extraction completed...: 0 file [00:16, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:16<?, ? url/s]
# Dl Size...:  46%|████▌     | 51/111 [00:16<00:23,  2.55 MiB/s]
#
# Extraction completed...: 0 file [00:16, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:16<?, ? url/s]
# Dl Size...:  47%|████▋     | 52/111 [00:16<00:21,  2.69 MiB/s]
#
# Extraction completed...: 0 file [00:16, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:17<?, ? url/s]
# Dl Size...:  48%|████▊     | 53/111 [00:17<00:21,  2.76 MiB/s]
#
# Extraction completed...: 0 file [00:17, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:17<?, ? url/s]
# Dl Size...:  49%|████▊     | 54/111 [00:17<00:20,  2.73 MiB/s]
#
# Extraction completed...: 0 file [00:17, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:18<?, ? url/s]
# Dl Size...:  50%|████▉     | 55/111 [00:18<00:21,  2.57 MiB/s]
#
# Extraction completed...: 0 file [00:18, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:18<?, ? url/s]
# Dl Size...:  50%|█████     | 56/111 [00:18<00:21,  2.58 MiB/s]
#
# Extraction completed...: 0 file [00:18, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:18<?, ? url/s]
# Dl Size...:  51%|█████▏    | 57/111 [00:18<00:20,  2.67 MiB/s]
#
# Extraction completed...: 0 file [00:18, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:19<?, ? url/s]
# Dl Size...:  52%|█████▏    | 58/111 [00:19<00:19,  2.70 MiB/s]
#
# Extraction completed...: 0 file [00:19, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:19<?, ? url/s]
# Dl Size...:  53%|█████▎    | 59/111 [00:19<00:22,  2.35 MiB/s]
#
# Extraction completed...: 0 file [00:19, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:20<?, ? url/s]
# Dl Size...:  54%|█████▍    | 60/111 [00:20<00:23,  2.21 MiB/s]
#
# Extraction completed...: 0 file [00:20, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:20<?, ? url/s]
# Dl Size...:  55%|█████▍    | 61/111 [00:20<00:22,  2.22 MiB/s]
#
# Extraction completed...: 0 file [00:20, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:21<?, ? url/s]
# Dl Size...:  56%|█████▌    | 62/111 [00:21<00:21,  2.25 MiB/s]
#
# Extraction completed...: 0 file [00:21, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:21<?, ? url/s]
# Dl Size...:  57%|█████▋    | 63/111 [00:21<00:20,  2.30 MiB/s]
#
# Extraction completed...: 0 file [00:21, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:21<?, ? url/s]
# Dl Size...:  58%|█████▊    | 64/111 [00:21<00:19,  2.37 MiB/s]
#
# Extraction completed...: 0 file [00:21, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:22<?, ? url/s]
# Dl Size...:  59%|█████▊    | 65/111 [00:22<00:18,  2.47 MiB/s]
#
# Extraction completed...: 0 file [00:22, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:22<?, ? url/s]
# Dl Size...:  59%|█████▉    | 66/111 [00:22<00:17,  2.53 MiB/s]
#
# Extraction completed...: 0 file [00:22, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:23<?, ? url/s]
# Dl Size...:  60%|██████    | 67/111 [00:23<00:17,  2.53 MiB/s]
#
# Extraction completed...: 0 file [00:23, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:23<?, ? url/s]
# Dl Size...:  61%|██████▏   | 68/111 [00:23<00:16,  2.55 MiB/s]
#
# Extraction completed...: 0 file [00:23, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:23<?, ? url/s]
# Dl Size...:  62%|██████▏   | 69/111 [00:23<00:16,  2.50 MiB/s]
#
# Extraction completed...: 0 file [00:23, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:24<?, ? url/s]
# Dl Size...:  63%|██████▎   | 70/111 [00:24<00:16,  2.56 MiB/s]
#
# Extraction completed...: 0 file [00:24, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:24<?, ? url/s]
# Dl Size...:  64%|██████▍   | 71/111 [00:24<00:14,  2.68 MiB/s]
#
# Extraction completed...: 0 file [00:24, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:24<?, ? url/s]
# Dl Size...:  65%|██████▍   | 72/111 [00:24<00:14,  2.64 MiB/s]
#
# Extraction completed...: 0 file [00:24, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:25<?, ? url/s]
# Dl Size...:  66%|██████▌   | 73/111 [00:25<00:14,  2.66 MiB/s]
#
# Extraction completed...: 0 file [00:25, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:25<?, ? url/s]
# Dl Size...:  67%|██████▋   | 74/111 [00:25<00:13,  2.66 MiB/s]
#
# Extraction completed...: 0 file [00:25, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:26<?, ? url/s]
# Dl Size...:  68%|██████▊   | 75/111 [00:26<00:14,  2.55 MiB/s]
#
# Extraction completed...: 0 file [00:26, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:26<?, ? url/s]
# Dl Size...:  68%|██████▊   | 76/111 [00:26<00:14,  2.44 MiB/s]
#
# Extraction completed...: 0 file [00:26, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:27<?, ? url/s]
# Dl Size...:  69%|██████▉   | 77/111 [00:27<00:15,  2.22 MiB/s]
#
# Extraction completed...: 0 file [00:27, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:27<?, ? url/s]
# Dl Size...:  70%|███████   | 78/111 [00:27<00:15,  2.14 MiB/s]
#
# Extraction completed...: 0 file [00:27, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:28<?, ? url/s]
# Dl Size...:  71%|███████   | 79/111 [00:28<00:14,  2.14 MiB/s]
#
# Extraction completed...: 0 file [00:28, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:28<?, ? url/s]
# Dl Size...:  72%|███████▏  | 80/111 [00:28<00:14,  2.11 MiB/s]
#
# Extraction completed...: 0 file [00:28, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:29<?, ? url/s]
# Dl Size...:  73%|███████▎  | 81/111 [00:29<00:14,  2.07 MiB/s]
#
# Extraction completed...: 0 file [00:29, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:29<?, ? url/s]
# Dl Size...:  74%|███████▍  | 82/111 [00:29<00:13,  2.08 MiB/s]
#
# Extraction completed...: 0 file [00:29, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:29<?, ? url/s]
# Dl Size...:  75%|███████▍  | 83/111 [00:29<00:12,  2.15 MiB/s]
#
# Extraction completed...: 0 file [00:29, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:30<?, ? url/s]
# Dl Size...:  76%|███████▌  | 84/111 [00:30<00:12,  2.12 MiB/s]
#
# Extraction completed...: 0 file [00:30, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:30<?, ? url/s]
# Dl Size...:  77%|███████▋  | 85/111 [00:30<00:12,  2.09 MiB/s]
#
# Extraction completed...: 0 file [00:30, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:31<?, ? url/s]
# Dl Size...:  77%|███████▋  | 86/111 [00:31<00:12,  2.05 MiB/s]
#
# Extraction completed...: 0 file [00:31, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:31<?, ? url/s]
# Dl Size...:  78%|███████▊  | 87/111 [00:31<00:11,  2.02 MiB/s]
#
# Extraction completed...: 0 file [00:31, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:32<?, ? url/s]
# Dl Size...:  79%|███████▉  | 88/111 [00:32<00:11,  2.06 MiB/s]
#
# Extraction completed...: 0 file [00:32, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:32<?, ? url/s]
# Dl Size...:  80%|████████  | 89/111 [00:32<00:10,  2.11 MiB/s]
#
# Extraction completed...: 0 file [00:32, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:33<?, ? url/s]
# Dl Size...:  81%|████████  | 90/111 [00:33<00:09,  2.25 MiB/s]
#
# Extraction completed...: 0 file [00:33, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:33<?, ? url/s]
# Dl Size...:  82%|████████▏ | 91/111 [00:33<00:08,  2.34 MiB/s]
#
# Extraction completed...: 0 file [00:33, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:34<?, ? url/s]
# Dl Size...:  83%|████████▎ | 92/111 [00:34<00:08,  2.36 MiB/s]
#
# Extraction completed...: 0 file [00:34, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:34<?, ? url/s]
# Dl Size...:  84%|████████▍ | 93/111 [00:34<00:07,  2.52 MiB/s]
#
# Extraction completed...: 0 file [00:34, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:34<?, ? url/s]
# Dl Size...:  85%|████████▍ | 94/111 [00:34<00:06,  2.65 MiB/s]
#
# Extraction completed...: 0 file [00:34, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:35<?, ? url/s]
# Dl Size...:  86%|████████▌ | 95/111 [00:35<00:05,  2.76 MiB/s]
#
# Extraction completed...: 0 file [00:35, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:35<?, ? url/s]
# Dl Size...:  86%|████████▋ | 96/111 [00:35<00:05,  2.75 MiB/s]
#
# Extraction completed...: 0 file [00:35, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:35<?, ? url/s]
# Dl Size...:  87%|████████▋ | 97/111 [00:35<00:04,  2.82 MiB/s]
#
# Extraction completed...: 0 file [00:35, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:36<?, ? url/s]
# Dl Size...:  88%|████████▊ | 98/111 [00:36<00:04,  2.97 MiB/s]
#
# Extraction completed...: 0 file [00:36, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:36<?, ? url/s]
# Dl Size...:  89%|████████▉ | 99/111 [00:36<00:04,  2.83 MiB/s]
#
# Extraction completed...: 0 file [00:36, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:36<?, ? url/s]
# Dl Size...:  90%|█████████ | 100/111 [00:36<00:04,  2.75 MiB/s]
#
# Extraction completed...: 0 file [00:36, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:37<?, ? url/s]
# Dl Size...:  91%|█████████ | 101/111 [00:37<00:03,  2.59 MiB/s]
#
# Extraction completed...: 0 file [00:37, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:37<?, ? url/s]
# Dl Size...:  92%|█████████▏| 102/111 [00:37<00:03,  2.55 MiB/s]
#
# Extraction completed...: 0 file [00:37, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:38<?, ? url/s]
# Dl Size...:  93%|█████████▎| 103/111 [00:38<00:03,  2.60 MiB/s]
#
# Extraction completed...: 0 file [00:38, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:38<?, ? url/s]
# Dl Size...:  94%|█████████▎| 104/111 [00:38<00:02,  2.56 MiB/s]
#
# Extraction completed...: 0 file [00:38, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:38<?, ? url/s]
# Dl Size...:  95%|█████████▍| 105/111 [00:38<00:02,  2.38 MiB/s]
#
# Extraction completed...: 0 file [00:38, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:39<?, ? url/s]
# Dl Size...:  95%|█████████▌| 106/111 [00:39<00:02,  2.29 MiB/s]
#
# Extraction completed...: 0 file [00:39, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:39<?, ? url/s]
# Dl Size...:  96%|█████████▋| 107/111 [00:39<00:01,  2.36 MiB/s]
#
# Extraction completed...: 0 file [00:39, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:40<?, ? url/s]
# Dl Size...:  97%|█████████▋| 108/111 [00:40<00:01,  2.41 MiB/s]
#
# Extraction completed...: 0 file [00:40, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:40<?, ? url/s]
# Dl Size...:  98%|█████████▊| 109/111 [00:40<00:00,  2.36 MiB/s]
#
# Extraction completed...: 0 file [00:40, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:41<?, ? url/s]
# Dl Size...:  99%|█████████▉| 110/111 [00:41<00:00,  2.31 MiB/s]
#
# Extraction completed...: 0 file [00:41, ? file/s]
# Dl Completed...:   0%|          | 0/1 [00:41<?, ? url/s]
# Dl Size...: 100%|██████████| 111/111 [00:41<00:00,  2.35 MiB/s]
#
# Dl Completed...: 100%|██████████| 1/1 [00:41<00:00, 41.68s/ url]
# Dl Size...: 100%|██████████| 111/111 [00:41<00:00,  2.35 MiB/s]
#
# Dl Completed...: 100%|██████████| 1/1 [00:41<00:00, 41.68s/ url]
# Dl Size...: 100%|██████████| 111/111 [00:41<00:00,  2.35 MiB/s]
#
# Extraction completed...:   0%|          | 0/1 [00:41<?, ? file/s]
#
# Dl Completed...: 100%|██████████| 1/1 [00:51<00:00, 41.68s/ url]
# Dl Size...: 100%|██████████| 111/111 [00:51<00:00,  2.35 MiB/s]
#
# Extraction completed...: 100%|██████████| 1/1 [00:51<00:00, 51.85s/ file]
# Dl Size...: 100%|██████████| 111/111 [00:51<00:00,  2.14 MiB/s]
# Dl Completed...: 100%|██████████| 1/1 [00:51<00:00, 51.86s/ url]
# Generating splits...:   0%|          | 0/4 [00:00<?, ? splits/s]
# Generating trainA examples...:   0%|          | 0/1067 [00:00<?, ? examples/s]
# Generating trainA examples...:  25%|██▌       | 267/1067 [00:00<00:00, 2668.29 examples/s]
# Generating trainA examples...:  50%|█████     | 538/1067 [00:00<00:00, 2678.55 examples/s]
# Generating trainA examples...:  77%|███████▋  | 819/1067 [00:00<00:00, 2715.43 examples/s]
#
# Shuffling cycle_gan-trainA.tfrecord...:   0%|          | 0/1067 [00:00<?, ? examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:   3%|▎         | 33/1067 [00:00<00:03, 327.69 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:   6%|▌         | 62/1067 [00:00<00:03, 313.10 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:   9%|▊         | 92/1067 [00:00<00:03, 306.38 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  12%|█▏        | 125/1067 [00:00<00:03, 311.76 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  15%|█▍        | 159/1067 [00:00<00:02, 319.62 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  18%|█▊        | 189/1067 [00:00<00:02, 312.47 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  21%|██        | 219/1067 [00:00<00:02, 302.98 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  24%|██▎       | 252/1067 [00:00<00:02, 307.44 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  26%|██▋       | 282/1067 [00:00<00:02, 304.76 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  30%|██▉       | 315/1067 [00:01<00:02, 309.30 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  32%|███▏      | 346/1067 [00:01<00:02, 261.17 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  35%|███▌      | 378/1067 [00:01<00:02, 274.26 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  38%|███▊      | 407/1067 [00:01<00:02, 259.64 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  41%|████      | 436/1067 [00:01<00:02, 266.47 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  44%|████▍     | 468/1067 [00:01<00:02, 280.32 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  47%|████▋     | 497/1067 [00:01<00:02, 278.68 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  50%|████▉     | 530/1067 [00:01<00:01, 292.22 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  52%|█████▏    | 560/1067 [00:01<00:01, 285.44 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  55%|█████▌    | 589/1067 [00:02<00:01, 283.14 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  58%|█████▊    | 618/1067 [00:02<00:01, 281.40 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  61%|██████    | 647/1067 [00:02<00:01, 275.58 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  63%|██████▎   | 675/1067 [00:02<00:01, 276.74 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  66%|██████▌   | 704/1067 [00:02<00:01, 275.61 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  69%|██████▉   | 736/1067 [00:02<00:01, 283.47 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  72%|███████▏  | 765/1067 [00:02<00:01, 270.30 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  74%|███████▍  | 794/1067 [00:02<00:00, 274.46 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  78%|███████▊  | 827/1067 [00:02<00:00, 288.02 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  80%|████████  | 857/1067 [00:02<00:00, 286.67 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  83%|████████▎ | 886/1067 [00:03<00:00, 282.01 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  86%|████████▌ | 915/1067 [00:03<00:00, 265.41 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  88%|████████▊ | 943/1067 [00:03<00:00, 267.05 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  91%|█████████ | 970/1067 [00:03<00:00, 260.35 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  93%|█████████▎| 997/1067 [00:03<00:00, 262.34 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  96%|█████████▌| 1024/1067 [00:03<00:00, 263.25 examples/s]
# Shuffling cycle_gan-trainA.tfrecord...:  99%|█████████▉| 1055/1067 [00:03<00:00, 274.88 examples/s]
# Generating splits...:  25%|██▌       | 1/4 [00:04<00:12,  4.19s/ splits]
# Generating trainB examples...:   0%|          | 0/1334 [00:00<?, ? examples/s]
# Generating trainB examples...:  20%|█▉        | 263/1334 [00:00<00:00, 2623.15 examples/s]
# Generating trainB examples...:  40%|███▉      | 529/1334 [00:00<00:00, 2632.59 examples/s]
# Generating trainB examples...:  59%|█████▉    | 789/1334 [00:00<00:00, 2620.82 examples/s]
# Generating trainB examples...:  78%|███████▊  | 1038/1334 [00:00<00:00, 2579.38 examples/s]
# Generating trainB examples...:  97%|█████████▋| 1291/1334 [00:00<00:00, 2562.61 examples/s]
#
# Shuffling cycle_gan-trainB.tfrecord...:   0%|          | 0/1334 [00:00<?, ? examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:   2%|▏         | 24/1334 [00:00<00:05, 233.69 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:   4%|▍         | 52/1334 [00:00<00:05, 243.18 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:   6%|▌         | 80/1334 [00:00<00:05, 250.77 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:   9%|▊         | 114/1334 [00:00<00:04, 271.41 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  11%|█         | 144/1334 [00:00<00:04, 277.65 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  13%|█▎        | 171/1334 [00:00<00:04, 272.43 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  15%|█▍        | 198/1334 [00:00<00:04, 257.57 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  17%|█▋        | 224/1334 [00:00<00:04, 255.81 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  19%|█▊        | 249/1334 [00:00<00:04, 253.93 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  21%|██        | 275/1334 [00:01<00:04, 254.19 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  22%|██▏       | 300/1334 [00:01<00:04, 247.24 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  24%|██▍       | 325/1334 [00:01<00:04, 247.77 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  26%|██▌       | 350/1334 [00:01<00:04, 244.45 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  28%|██▊       | 375/1334 [00:01<00:04, 234.98 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  30%|██▉       | 399/1334 [00:01<00:04, 232.51 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  32%|███▏      | 428/1334 [00:01<00:03, 247.12 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  34%|███▍      | 455/1334 [00:01<00:03, 253.08 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  36%|███▌      | 481/1334 [00:01<00:03, 246.34 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  38%|███▊      | 506/1334 [00:02<00:03, 221.07 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  40%|███▉      | 533/1334 [00:02<00:03, 232.35 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  42%|████▏     | 559/1334 [00:02<00:03, 237.98 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  44%|████▍     | 584/1334 [00:02<00:03, 239.84 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  46%|████▌     | 610/1334 [00:02<00:02, 244.61 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  48%|████▊     | 635/1334 [00:02<00:02, 236.37 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  49%|████▉     | 659/1334 [00:02<00:02, 226.58 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  51%|█████▏    | 685/1334 [00:02<00:02, 232.19 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  53%|█████▎    | 712/1334 [00:02<00:02, 242.11 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  55%|█████▌    | 739/1334 [00:02<00:02, 249.14 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  57%|█████▋    | 765/1334 [00:03<00:02, 243.46 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  59%|█████▉    | 790/1334 [00:03<00:02, 239.36 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  61%|██████▏   | 818/1334 [00:03<00:02, 248.39 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  63%|██████▎   | 844/1334 [00:03<00:01, 246.20 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  65%|██████▌   | 871/1334 [00:03<00:01, 252.47 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  68%|██████▊   | 902/1334 [00:03<00:01, 265.85 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  70%|██████▉   | 931/1334 [00:03<00:01, 270.99 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  72%|███████▏  | 959/1334 [00:03<00:01, 259.62 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  74%|███████▍  | 986/1334 [00:03<00:01, 247.51 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  76%|███████▌  | 1016/1334 [00:04<00:01, 261.20 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  78%|███████▊  | 1043/1334 [00:04<00:01, 251.84 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  80%|████████  | 1069/1334 [00:04<00:01, 242.89 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  82%|████████▏ | 1097/1334 [00:04<00:00, 249.69 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  84%|████████▍ | 1126/1334 [00:04<00:00, 258.97 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  86%|████████▋ | 1153/1334 [00:04<00:00, 258.23 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  88%|████████▊ | 1180/1334 [00:04<00:00, 251.51 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  90%|█████████ | 1206/1334 [00:04<00:00, 248.23 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  92%|█████████▏| 1231/1334 [00:04<00:00, 242.45 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  94%|█████████▍| 1256/1334 [00:05<00:00, 225.18 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  96%|█████████▌| 1282/1334 [00:05<00:00, 232.44 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...:  98%|█████████▊| 1306/1334 [00:05<00:00, 233.90 examples/s]
# Shuffling cycle_gan-trainB.tfrecord...: 100%|█████████▉| 1330/1334 [00:05<00:00, 230.88 examples/s]
# Generating splits...:  50%|█████     | 2/4 [00:10<00:09,  4.71s/ splits]
# Generating testA examples...:   0%|          | 0/120 [00:00<?, ? examples/s]
#
# Shuffling cycle_gan-testA.tfrecord...:   0%|          | 0/120 [00:00<?, ? examples/s]
# Shuffling cycle_gan-testA.tfrecord...:  25%|██▌       | 30/120 [00:00<00:00, 293.69 examples/s]
# Shuffling cycle_gan-testA.tfrecord...:  45%|████▌     | 54/120 [00:00<00:00, 273.29 examples/s]
# Shuffling cycle_gan-testA.tfrecord...:  65%|██████▌   | 78/120 [00:00<00:00, 257.59 examples/s]
# Shuffling cycle_gan-testA.tfrecord...:  89%|████████▉ | 107/120 [00:00<00:00, 266.51 examples/s]
# Generating splits...:  75%|███████▌  | 3/4 [00:10<00:03,  3.46s/ splits]
# Generating testB examples...:   0%|          | 0/140 [00:00<?, ? examples/s]
#
# Shuffling cycle_gan-testB.tfrecord...:   0%|          | 0/140 [00:00<?, ? examples/s]
# Shuffling cycle_gan-testB.tfrecord...:  19%|█▊        | 26/140 [00:00<00:00, 254.11 examples/s]
# Shuffling cycle_gan-testB.tfrecord...:  34%|███▎      | 47/140 [00:00<00:00, 238.87 examples/s]
# Shuffling cycle_gan-testB.tfrecord...:  54%|█████▎    | 75/140 [00:00<00:00, 247.98 examples/s]
# Shuffling cycle_gan-testB.tfrecord...:  69%|██████▊   | 96/140 [00:00<00:00, 234.49 examples/s]
# Shuffling cycle_gan-testB.tfrecord...:  87%|████████▋ | 122/140 [00:00<00:00, 239.26 examples/s]
# Dataset cycle_gan downloaded and prepared to /Users/jules/tensorflow_datasets/cycle_gan/horse2zebra/2.0.0. Subsequent calls will reuse this data.

# %%
BUFFER_SIZE = 1000
BATCH_SIZE = 1
IMG_WIDTH = 256
IMG_HEIGHT = 256

# %%
# image preprocessing helpers

def load(image_file):
    image = tf.io.read_file(image_file)
    image = tf.image.decode_jpeg(image)
    
    w = tf.shape(image)[1]
    w = w // 2

    real_image = image[:, :w, :]
    input_image = image[:, w:, :]

    input_image = tf.cast(input_image, tf.float32)
    real_image = tf.cast(real_image, tf.float32)
    return input_image, real_image


def random_crop(image):
    return tf.image.random_crop(
        image, 
        size=[IMG_HEIGHT, IMG_WIDTH, 3]
    )


# normalizes images to [-1, 1]
def normalize(image):
    return tf.cast(image, tf.float32) / 127.5 - 1


@tf.function
def random_jitter(image):
    # resize to 286 x 286 x 3
    image = tf.image.resize(
        image, 
        [286, 286], 
        method=tf.image.ResizeMethod.NEAREST_NEIGHBOR
    )
    # randomly crop to 256 x 256 x 3
    image = random_crop(image)
    # random mirroring
    image = tf.image.random_flip_left_right(image)
    return image


def preprocess_image_train(image, label):
    image = random_jitter(image)
    image = normalize(image)
    return image


def preprocess_image_test(image, label):
    return normalize(image)

# %%
# setup data

train_horses = (
    train_horses.map(preprocess_image_train)
        .cache()
        .shuffle(BUFFER_SIZE)
        .batch(BATCH_SIZE)
)

train_zebras = (
    train_zebras.map(preprocess_image_train)
        .cache()
        .shuffle(BUFFER_SIZE)
        .batch(BATCH_SIZE)
)

test_horses = (
    test_horses.map(preprocess_image_test)
        .cache()
        .shuffle(BUFFER_SIZE)
        .batch(BATCH_SIZE)
)

test_zebras = (
    test_zebras.map(preprocess_image_test)
        .cache()
        .shuffle(BUFFER_SIZE)
        .batch(BATCH_SIZE)
)

# %%
sample_horse = next(iter(train_horses))
sample_zebra = next(iter(train_zebras))

plt.subplot(121)
plt.title("Horse")
plt.imshow(sample_horse[0] * 0.5 + 0.5)

plt.subplot(122)
plt.title("Horse with random jitter")
plt.imshow(random_jitter(sample_horse[0]) * 0.5 + 0.5)

# %%
plt.subplot(121)
plt.title("Zebra")
plt.imshow(sample_zebra[0] * 0.5 + 0.5)

plt.subplot(122)
plt.title("Zebra with random jitter")
plt.imshow(random_jitter(sample_zebra[0]) * 0.5 + 0.5)

# %% [markdown]
# ## The Model

# %%
import tensorflow as tf
from tensorflow.keras.layers import (
    BatchNormalization, 
    Concatenate,
    Conv2D, 
    Conv2DTranspose,
    Dropout,
    Input,
    Layer,
    LeakyReLU,
    ReLU,
    ZeroPadding2D,
)

class InstanceNormalization(Layer):
    """
    Instance Normalization Layer (https://arxiv.org/abs/1607.08022).
    """

    def __init__(self, epsilon=1e-5):
        super(InstanceNormalization, self).__init__()
        self.epsilon = epsilon

    def build(self, input_shape):
        self.scale = self.add_weight(
            name="scale",
            shape=input_shape[-1:],
            initializer=tf.random_normal_initializer(1.0, 0.02),
            trainable=True
        )

        self.offset = self.add_weight(
            name="offset",
            shape=input_shape[-1:],
            initializer="zeros",
            trainable=True,
        )

    def call(self, x):
        mean, variance = tf.nn.moments(x, axes=[1, 2], keepdims=True)
        inv = tf.math.rsqrt(variance + self.epsilon)
        normalized = (x - mean) * inv
        return self.scale * normalized + self.offset


def downsample(filters, size, norm_type="batchnorm", apply_norm=True):
    """
    Downsamples an input.
    """
    initializer = tf.random_normal_initializer(0.0, 0.02)
    model = tf.keras.Sequential()
    model.add(
        Conv2D(
            filters, 
            size, 
            strides=2, 
            padding="same", 
            kernel_initializer=initializer,
        )
    )

    if apply_norm:
        if norm_type.lower() == "batchnorm":
            model.add(BatchNormalization())
        elif norm_type.lower() == "instancenorm":
            model.add(InstanceNormalization())
    
    model.add(LeakyReLU())
    return model


def upsample(filters, size, norm_type="batchnorm", apply_dropout=False):
    """
    Upsamples an input.
    """
    initializer = tf.random_normal_initializer(0.0, 0.02)

    model = tf.keras.Sequential()
    model.add(
        Conv2DTranspose(
            filters,
            size,
            strides=2,
            padding="same",
            kernel_initializer=initializer,
            use_bias=False,
        )
    )

    if norm_type.lower() == "batchnorm":
        model.add(BatchNormalization())
    elif norm_type.lower() == "instancenorm":
        model.add(InstanceNormalization())

    if apply_dropout:
        model.add(Dropout(0.5))
    
    model.add(ReLU())

    return model
    

def unet_generator(output_channels, norm_type="batchnorm"):
    """
    Modified u-net generator model (https://arxiv.org/abs/1611.07004).
    """
    down_stack = [
        downsample(64, 4, norm_type, apply_norm=False), # (bs, 128, 128, 64)
        downsample(128, 4, norm_type), # (bs, 64, 64, 128)
        downsample(256, 4, norm_type), # (bs, 32, 32, 256)
        downsample(512, 4, norm_type), # (bs, 16, 16, 512)
        downsample(512, 4, norm_type), # (bs, 8, 8, 512)
        downsample(512, 4, norm_type), # (bs, 4, 4, 512)
        downsample(512, 4, norm_type), # (bs, 2, 2, 512)
        downsample(512, 4, norm_type), # (bs, 1, 1, 512)
    ]

    up_stack = [
        upsample(512, 4, norm_type, apply_dropout=True), # (bs, 2, 2, 1024)
        upsample(512, 4, norm_type, apply_dropout=True), # (bs, 4, 4, 1024)
        upsample(512, 4, norm_type, apply_dropout=True), # (bs, 8, 8, 1024)
        upsample(512, 4, norm_type), # (bs, 16, 165, 1024)
        upsample(256, 4, norm_type), # (bs, 32, 32, 512)
        upsample(128, 4, norm_type), # (bs, 64, 64, 256)
        upsample(64, 4, norm_type), # (bs, 128, 128, 128)
    ]

    initializer = tf.random_normal_initializer(0.0, 0.02)
    last = Conv2DTranspose(
        output_channels,
        4,
        strides=2,
        padding="same",
        kernel_initializer=initializer,
        activation="tanh",
    ) # (bs, 256, 256, 3)

    concat = Concatenate()
    
    inputs = Input(shape=[None, None, 3])
    x = inputs

    # downsampling through the model
    skips = []
    for down in down_stack:
        x = down(x)
        skips.append(x)

    skips = reversed(skips[:-1])

    # upsampling and establishing the skip connections
    for up, skip, in zip(up_stack, skips):
        x = up(x)
        x = concat([x, skip])

    x = last(x)

    return tf.keras.Model(inputs=inputs, outputs=x)


def discriminator(norm_type="batchnorm", target=True):
    """
    PatchGan discriminator model (https://arxiv.org/abs/1611.07004).
    """
    initializer = tf.random_normal_initializer(0.0, 0.02)

    inp = Input(shape=[None, None, 3], name="input_image")
    x = inp

    if target:
        tar = Input(shape=[None, None, 3], name="target_image")
        x = tf.keras.layers.concatenate([inp, tar]) # (bs, 256, 256, channels * 2)

    down1 = downsample(64, 4, norm_type, False)(x) # (bs, 128, 128, 64)
    down2 = downsample(128, 4, norm_type)(down1) # (bs, 64, 64, 128)
    down3 = downsample(256, 4, norm_type)(down2) # (bs, 32, 32, 256)

    zero_pad1 = ZeroPadding2D()(down3) # (bs, 34, 34, 256)
    conv = Conv2D(
        512,
        4,
        strides=1,
        kernel_initializer=initializer,
        use_bias=False
    )(zero_pad1) # (bs, 31, 31, 512)

    if norm_type.lower() == "batchnorm":
        norm1 = BatchNormalization()(conv)
    elif norm_type.lower() == "instancenorm":
        norm1 = InstanceNormalization()(conv)

    leaky_relu = LeakyReLU()(norm1)
    zero_pad2 = ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)
    last = Conv2D(
        1,
        4,
        strides=1,
        kernel_initializer=initializer,
    )(zero_pad2) # (bs, 30, 30, 1)

    if target:
        return tf.keras.Model(inputs=[inp, tar], outputs=last)
    else:
        return tf.keras.Model(inputs=inp, outputs=last)

# %%
OUTPUT_CHANNELS = 3

generator_g = unet_generator(OUTPUT_CHANNELS, norm_type="instancenorm")
generator_f = unet_generator(OUTPUT_CHANNELS, norm_type="instancenorm")

discriminator_x = discriminator(norm_type="instancenorm", target=False)
discriminator_y = discriminator(norm_type="instancenorm", target=False)

# %%
to_zebra = generator_g(sample_horse)
to_horse = generator_f(sample_zebra)
plt.figure(figsize=(8, 8))
contrast = 8

imgs = [sample_horse, to_zebra, sample_zebra, to_horse]
title = ["Horse", "To Zebra", "Zebra", "To Horse"]

for i in range(len(imgs)):
    plt.subplot(2, 2, i + 1)
    plt.title(title[i])
    if i % 2 == 0:
        plt.imshow(imgs[i][0] * 0.5 + 0.5)
    else:
        plt.imshow(imgs[i][0] * 0.5 * contrast + 0.5)
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(8, 8))

plt.subplot(121)
plt.title("Is a real zebra?")
plt.imshow(discriminator_y(sample_zebra)[0, ..., -1], cmap="RdBu_r")

plt.subplot(122)
plt.title("Is a real horse?")
plt.imshow(discriminator_x(sample_horse)[0, ..., -1], cmap="RdBu_r")

plt.show()

# %% [markdown]
# ## Loss functions

# %%
LAMBDA = 10

loss_obj = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(real, generated):
    real_loss = loss_obj(tf.ones_like(real), real)
    generated_loss = loss_obj(tf.zeros_like(generated), generated)
    total_disc_loss = real_loss + generated_loss
    return total_disc_loss * 0.5


def generator_loss(generated):
    return loss_obj(tf.ones_like(generated), generated)


def calc_cycle_loss(real_image, cycled_image):
    loss1 = tf.reduce_mean(tf.abs(real_image - cycled_image))
    return LAMBDA * loss1


def identity_loss(real_image, same_image):
    loss = tf.reduce_mean(tf.abs(real_image - same_image))
    return LAMBDA * 0.5 * loss

# %%
def optimizer():
    return tf.keras.optimizers.Adam(2e-4, beta_1=0.5)


generator_g_optimizer = optimizer()
generator_f_optimizer = optimizer()

discriminator_x_optimizer = optimizer()
discriminator_y_optimizer = optimizer()

# %% [markdown]
# ## Checkpoints

# %%
checkpoint_path = "./checkpoints/train"

ckpt = tf.train.Checkpoint(
    generator_g=generator_g,
    generator_f=generator_f,
    discriminator_x=discriminator_x,
    discriminator_y=discriminator_y,
    generator_g_optimizer=generator_g_optimizer,
    generator_f_optimizer=generator_f_optimizer,
    discriminator_x_optimizer=discriminator_x_optimizer,
    discriminator_y_optimizer=discriminator_y_optimizer,
)

ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# if a checkpoint exists, restore the latest checkpoint.
if ckpt_manager.latest_checkpoint:
    ckpt.restore(ckpt_manager.latest_checkpoint)
    print("Latest checkpoint restored!")

# %% [markdown]
# ## Training

# %%
EPOCHS = 40

def generate_images(model, test_input):
    prediction = model(test_input)

    plt.figure(figsize=(12, 12))

    display_list = [test_input[0], prediction[0]]
    title = ["Input Image", "Predicted Image"]

    for i in range(2):
        plt.subplot(1, 2, i + 1)
        plt.title(title[i])
        plt.imshow(display_list[i] * 0.5 + 0.5)
        plt.axis("off")
    plt.show()


@tf.function
def train_step(real_x, real_y):
    # persistent is set to True because the tape is used more than 
    # once to calcualte the gradients.
    with tf.GradientTape(persistent=True) as tape:
        # Generator G translates X -> Y
        # Generator F translates Y -> X.

        ##
        # 1. Get the predictions
        ##
        fake_y = generator_g(real_x, training=True)
        cycled_x = generator_f(fake_y, training=True)

        fake_x = generator_f(real_y, training=True)
        cycled_y = generator_g(fake_x, training=True)

        # same_x and same_y are used for identity loss.
        same_x = generator_f(real_x, training=True)
        same_y = generator_g(real_y, training=True)

        disc_real_x = discriminator_x(real_x, training=True)
        disc_real_y = discriminator_y(real_y, training=True)

        disc_fake_x = discriminator_x(fake_x, training=True)
        disc_fake_y = discriminator_y(fake_y, training=True)

        ##
        # 2. Calculate the loss.
        ##
        gen_g_loss = generator_loss(disc_fake_y)
        gen_f_loss = generator_loss(disc_fake_x)

        total_cycle_loss = calc_cycle_loss(real_x, cycled_x) + calc_cycle_loss(real_y, cycled_y)

        # total generator loss = adversarial loss + cycle loss
        total_gen_g_loss = gen_g_loss + total_cycle_loss + identity_loss(real_y, same_y)
        total_gen_f_loss = gen_f_loss + total_cycle_loss + identity_loss(real_x, same_x)

        disc_x_loss = discriminator_loss(disc_real_x, disc_fake_x)
        disc_y_loss = discriminator_loss(disc_real_y, disc_fake_y)

    ##
    # 3. Calculate the gradients for the generator and discriminator
    ##
    generator_g_gradients = tape.gradient(
        total_gen_g_loss, generator_g.trainable_variables
    )
    generator_f_gradients = tape.gradient(
        total_gen_f_loss, generator_f.trainable_variables
    )

    discriminator_x_gradients = tape.gradient(
        disc_x_loss, discriminator_x.trainable_variables
    )
    discriminator_y_gradients = tape.gradient(
        disc_y_loss, discriminator_y.trainable_variables
    )

    ##
    # 4. Apply gradients to optimizer
    ##
    generator_g_optimizer.apply_gradients(
        zip(generator_g_gradients, generator_g.trainable_variables)
    )

    generator_f_optimizer.apply_gradients(
        zip(generator_f_gradients, generator_f.trainable_variables)
    )

    discriminator_x_optimizer.apply_gradients(
        zip(discriminator_x_gradients, discriminator_x.trainable_variables)
    )

    discriminator_y_optimizer.apply_gradients(
        zip(discriminator_y_gradients, discriminator_y.trainable_variables)
    )

# %%
import time

for epoch in range(EPOCHS):
    start = time.time()
    n = 0
    for image_x, image_y in tf.data.Dataset.zip((train_horses, train_zebras)):
        train_step(image_x, image_y)
        if n % 10 == 0:
            print(".", end="")
        n += 1

    clear_output(wait=True)

    # use a consistent image (sample_horse) so that the progress of the model
    # is clearly visible.
    generate_images(generator_g, sample_horse)

    if (epoch + 1) % 5 == 0:
        ckpt_save_path = ckpt_manager.save()
        print(f"Saving checkpoint for epoch {epoch + 1} at {ckpt_save_path}")

    print(f"Time take for epoch {epoch + 1} is {time.time() - start} sec\n")

# %%
# Run the trained model on the test dataset
for inp in test_horses.take(5):
    generate_images(generator_g, inp)
